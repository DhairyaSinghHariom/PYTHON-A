# %% [markdown]
# <a href="https://colab.research.google.com/github/DhairyaSinghHariom/PYTHON-A/blob/main/basic%20python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Variable in Python

Name = "John" # String
Age = 20      # int
Height = 5.9  # float
It_blue = True # Boolean


print("Name:", Name)
print("Age:", Age)
print("Height:", Height)
print("It_blue:", It_blue)

# %%
# User Input

Name = input("Enter your name: ")
Age = int(input("Enter your age: "))

# %%
# operator
x = 3
y = 10
print( x + y)
print( x - y)
print(x * y)
print(x % y)
print(x / y)
print(x // y)
print(x ** y)

# %%
# Dcision Making

# if _else

age = int(input("Enter your age: "))
if age >= 18:
    print("You are eligible to vote")

else:
    print("You are not eligible to vote")
# Out:
# Enter your age: 12
# You are not eligible to vote

# %%
# If_elif_else

age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible to vote")
elif age >= 13:
    print("You are not eligible to vote")
else:
    print("You are too young to vote")
# Out:
# Enter your age: 13
# You are not eligible to vote

# %%
# Loop(While )

count = 0
while count < 10:
    print("Count is:", count)
    count += 1
# Out:
# Count is: 0
# Count is: 1
# Count is: 2
# Count is: 3
# Count is: 4
# Count is: 5
# Count is: 6
# Count is: 7
# Count is: 8
# Count is: 9

# %%
# Loop (For)

video_game = ["Game 1" , "Game 2" , "Game 3"]

for game in video_game:
    print(game)
# Out:
# Game 1
# Game 2
# Game 3

# %%
# List

video_game = ["Game 1" , "Game 2" , "Game 3"]

print(video_game[0])

video_game.append("Game 4")

print(video_game)

video_game.remove("Game 3")
print(video_game)

video_game.insert(2, "Game 3")
print(video_game)
# Out:
# Game 1
# ['Game 1', 'Game 2', 'Game 3', 'Game 4']
# ['Game 1', 'Game 2', 'Game 4']
# ['Game 1', 'Game 2', 'Game 3', 'Game 4']

# %%
# Function

def say_hello(person_name):
  print("hello," + person_name + "from you very first function")

say_hello("John")

def multiply(a , b):
  return a * b

  result = multiply(10 , 5)
  print("result:",result)
# Out:
# hello,Johnfrom you very first function

# %%
import random

secret_number = random.randint(1, 10)
attempts = 3

print("I'm thinking of a number between 1 and 10")

while attempts > 0:
    guess = int(input("Take a guess: "))

    if guess == secret_number:
        print("Congratulations! You guessed the number!")
        break
    elif guess < secret_number:
        print("Too low! Try again.")
    else:
        print("Too high! Try again.")

    attempts -= 1

    if attempts == 0:
        print("Sorry, you've run out of attempts.")
        print(f"The number was {secret_number}")
# Out:
# I'm thinking of a number between 1 and 10
# Take a guess: 8
# Too low! Try again.
# Take a guess: 6
# Too low! Try again.
# Take a guess: 2
# Too low! Try again.
# Sorry, you've run out of attempts.
# The number was 9
